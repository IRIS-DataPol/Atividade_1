# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('indice-cidades-empreendedoras.csv', index_col=0).fillna(0)
df
# Out:
#                          UF Tempo de Viabilidade de Localização  \
# Determinante             UF                Ambiente Regulatório
# Subdeterminante          UF                  Tempo de Processos
# Fonte                    UF                             REDESIM
# São Paulo                SP                                  13
# Florianópolis            SC                                  92
# ...                      ..                                 ...
# Olinda                   PE                                  79
# Vitória da Conquista     BA                                  68
# Paulista                 PE                                  78
# Jaboatão dos Guararapes  PE                                  72
# Caruaru                  PE                                  67
#
#                         Tempo de Registro, Cadastro e Viabilidade de Nome  \
# Determinante                                         Ambiente Regulatório
# Subdeterminante                                        Tempo de Processos
# Fonte                                                             REDESIM
# São Paulo                                                              40
# Florianópolis                                                          18
# ...                                                                   ...
# Olinda                                                                 75
# Vitória da Conquista                                                   97
# Paulista                                                               75
# Jaboatão dos Guararapes                                                75
# Caruaru                                                                75
#
#                         Taxa de Congestionamento em Tribunais  \
# Determinante                             Ambiente Regulatório
# Subdeterminante                            Tempo de Processos
# Fonte                                                     CNJ
# São Paulo                                                  11
# Florianópolis                                              16
# ...                                                       ...
# Olinda                                                     85
# Vitória da Conquista                                       60
# Paulista                                                   87
# Jaboatão dos Guararapes                                    36
# Caruaru                                                    47
#
#                         Soma de Tempo de Processos  \
# Determinante                  Ambiente Regulatório
# Subdeterminante                 Tempo de Processos
# Fonte                                            0
# São Paulo                                       20
# Florianópolis                                   17
# ...                                            ...
# Olinda                                          89
# Vitória da Conquista                            99
# Paulista                                        90
# Jaboatão dos Guararapes                         56
# Caruaru                                         61
#
#                         Índice de Tempo de Processos Alíquota Interna do ICMS  \
# Determinante                    Ambiente Regulatório     Ambiente Regulatório
# Subdeterminante                   Tempo de Processos               Tributação
# Fonte                                              0           Siconfi e IBGE
# São Paulo                                         20                       12
# Florianópolis                                     17                       50
# ...                                              ...                      ...
# Olinda                                            89                       72
# Vitória da Conquista                              99                       78
# Paulista                                          90                       72
# Jaboatão dos Guararapes                           56                       72
# Caruaru                                           61                       72
#
#                         Alíquota Interna do IPTU Alíquota Interna do ISS  \
# Determinante                Ambiente Regulatório    Ambiente Regulatório
# Subdeterminante                       Tributação              Tributação
# Fonte                             Siconfi e IBGE          Siconfi e IBGE
# São Paulo                                     92                      95
# Florianópolis                                 95                      89
# ...                                          ...                     ...
# Olinda                                        25                      80
# Vitória da Conquista                          37                      60
# Paulista                                      59                      21
# Jaboatão dos Guararapes                       52                      30
# Caruaru                                       55                      50
#
#                         Qualidade da Gestão Fiscal  ...  \
# Determinante                  Ambiente Regulatório  ...
# Subdeterminante                         Tributação  ...
# Fonte                                       Firjan  ...
# São Paulo                                       22  ...
# Florianópolis                                   56  ...
# ...                                            ...  ...
# Olinda                                          57  ...
# Vitória da Conquista                            60  ...
# Paulista                                        64  ...
# Jaboatão dos Guararapes                         65  ...
# Caruaru                                         51  ...
#
#                         Conhecimento sobre Processos de Abertura de Negócios  \
# Determinante                                                       Cultura
# Subdeterminante                                Imagem do Empreendedorismo
# Fonte                                                          Mind Miners
# São Paulo                                                               21
# Florianópolis                                                           49
# ...                                                                    ...
# Olinda                                                                  10
# Vitória da Conquista                                                    54
# Paulista                                                                10
# Jaboatão dos Guararapes                                                 10
# Caruaru                                                                 10
#
#                         Conhecimento de Riscos na Abertura de Novos Negócios  \
# Determinante                                                       Cultura
# Subdeterminante                                Imagem do Empreendedorismo
# Fonte                                                          Mind Miners
# São Paulo                                                               60
# Florianópolis                                                           89
# ...                                                                    ...
# Olinda                                                                  14
# Vitória da Conquista                                                    10
# Paulista                                                                14
# Jaboatão dos Guararapes                                                 14
# Caruaru                                                                 14
#
#                         Grau de Esforço para se Tornar Empreendedor  \
# Determinante                                                Cultura
# Subdeterminante                         Imagem do Empreendedorismo
# Fonte                                                   Mind Miners
# São Paulo                                                        32
# Florianópolis                                                    83
# ...                                                             ...
# Olinda                                                            5
# Vitória da Conquista                                             11
# Paulista                                                          5
# Jaboatão dos Guararapes                                           5
# Caruaru                                                           5
#
#                         Pesquisas sobre Empreendedorismo   Soma de Cultura  \
# Determinante                                      Cultura          Cultura
# Subdeterminante               Imagem do Empreendedorismo   Soma de Cultura
# Fonte                                       Google Trends                0
# São Paulo                                              53               59
# Florianópolis                                          54               86
# ...                                                   ...              ...
# Olinda                                                 54                6
# Vitória da Conquista                                   54               14
# Paulista                                               54                6
# Jaboatão dos Guararapes                                54                6
# Caruaru                                                54                6
#
#                          Índice de Cultura    ice1    ice2  ice1 + ice2  \
# Determinante                       Cultura  Índice  Índice       Índice
# Subdeterminante          Índice de Cultura  Índice  Índice       Índice
# Fonte                                    0    ice1    ice2  ice1 + ice2
# São Paulo                               59       2       1            1
# Florianópolis                           86       1      55            2
# ...                                    ...     ...     ...          ...
# Olinda                                   6      67      98           96
# Vitória da Conquista                    14      63      99           97
# Paulista                                 6      73      97           98
# Jaboatão dos Guararapes                  6      90      91           99
# Caruaru                                  6      59     100          100
#
#                          ICE 2020
# Determinante               Índice
# Subdeterminante            Índice
# Fonte                    ICE 2020
# São Paulo                       1
# Florianópolis                   2
# ...                           ...
# Olinda                         96
# Vitória da Conquista           97
# Paulista                       98
# Jaboatão dos Guararapes        99
# Caruaru                       100
#
# [103 rows x 92 columns]

# %% [markdown]
# # Atividade 1
# ## Pergunta 1.1: Quais as três cidades com melhor posição geral?

# %%
ICE2020 = pd.to_numeric(df['ICE 2020'], errors='coerce')
ICE2020.sort_values(inplace=True)
for cidade in ICE2020.index[:3]:
    print(cidade)
# Out:
# São Paulo
# Florianópolis
# Osasco

# %% [markdown]
# ## Pergunta 1.2: Quais as três cidades que apresentam os maiores índices para cada um dos 7 determinantes?

# %%
subdeterminantes = [column for column in df.columns if column.startswith('Índice')]

subdeterminantes
# Out:
# ['Índice de Tempo de Processos',
#  'Índice de Tributação',
#  'Índice de Complexidade Burocrática',
#  'Índice de Ambiente Regulatório',
#  'Índice de Transporte Interurbano',
#  'Índice de Condições Urbanas',
#  'Índice de Infraestrutura',
#  'Índice de Desenvolvimento Humano ',
#  'Índice de Desenvolvimento Econômico',
#  'Índice de Clientes Potenciais ',
#  'Índice de Mercado',
#  'Índice de Acesso a Capital',
#  'Índice de Inputs',
#  'Índice de Outputs',
#  'Índice de Inovação',
#  'Índice de Acesso e Qualidade da Mão de Obra Básica',
#  'Índice de Acesso e Qualidade da Mão de Obra Qualificada ',
#  'Índice de Capital Humano',
#  'Índice de Cultura']

# %%
determinantes = ['Índice de ' + determinante for determinante in df.loc['Determinante'].unique()[1:-1]]

determinantes
# Out:
# ['Índice de Ambiente Regulatório',
#  'Índice de Infraestrutura',
#  'Índice de Mercado',
#  'Índice de Acesso a Capital',
#  'Índice de Inovação',
#  'Índice de Capital Humano',
#  'Índice de Cultura']

# %%
for determinante in determinantes:
    print(f"Determinante: {determinante}")
    série = pd.to_numeric(df[determinante], errors='coerce')
    série.sort_values(inplace=True)
    for index, cidade in enumerate(série.index[1:4]):
        print(f"{index + 1}: {cidade}")
    print('\n')
# Out:
# Determinante: Índice de Ambiente Regulatório
# 1: Macapá
# 2: Vitória
# 3: São Gonçalo
#
#
# Determinante: Índice de Infraestrutura
# 1: São Paulo
# 2: Recife
# 3: Limeira
#
#
# Determinante: Índice de Mercado
# 1: Jundiaí
# 2: Canoas
# 3: Brasília
#
#
# Determinante: Índice de Acesso a Capital
# 1: São Paulo
# 2: Osasco
# 3: Porto Alegre
#
#
# Determinante: Índice de Inovação
# 1: Florianópolis
# 2: Caxias do Sul
# 3: Campinas
#
#
# Determinante: Índice de Capital Humano
# 1: Florianópolis
# 2: Vitória
# 3: Niterói
#
#
# Determinante: Índice de Cultura
# 1: Porto Velho
# 2: Manaus
# 3: Rio Branco

# %% [markdown]
# ## Pergunta 1.3: Quais as três Unidades Federativas (UFs) com mais cidades no Ranking?

# %%
for index, UF in enumerate(df["UF"].value_counts()[:3].index):
    print(f"{index + 1}: {UF}")
# Out:
# 1: SP
# 2: RJ
# 3: MG

# %% [markdown]
# # Atividades 2 e 3
# ## Interface para acessar dados de uma cidade

# %%
def getDados(cidade):
    print(f"Dados para {cidade}")
    for determinante in determinantes:
        print(f"\t{determinante}: {df.loc[cidade][determinante]}")
    print()
    
getDados("São Paulo")
getDados("Recife")
getDados("Goiânia")
# Out:
# Dados para São Paulo
# 	Índice de Ambiente Regulatório: 4
# 	Índice de Infraestrutura: 1
# 	Índice de Mercado: 7
# 	Índice de Acesso a Capital: 1
# 	Índice de Inovação: 16
# 	Índice de Capital Humano: 60
# 	Índice de Cultura: 59
#
# Dados para Recife
# 	Índice de Ambiente Regulatório: 86
# 	Índice de Infraestrutura: 2
# 	Índice de Mercado: 76
# 	Índice de Acesso a Capital: 13
# 	Índice de Inovação: 21
# 	Índice de Capital Humano: 15
# 	Índice de Cultura: 5
#
# Dados para Goiânia
# 	Índice de Ambiente Regulatório: 35
# 	Índice de Infraestrutura: 22
# 	Índice de Mercado: 78
# 	Índice de Acesso a Capital: 14
# 	Índice de Inovação: 47
# 	Índice de Capital Humano: 33
# 	Índice de Cultura: 25
